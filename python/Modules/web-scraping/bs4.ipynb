# %%
from bs4 import BeautifulSoup
import requests

# %%
with open('simple.html') as html_file:
    soup = BeautifulSoup(html_file, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="">
#  <head>
#   <title>
#    Test - A Sample Website
#   </title>
#   <meta charset="utf-8"/>
#   <link href="css/normalize.css" rel="stylesheet"/>
#   <link href="css/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <h1 id="site_title">
#    Test Website
#   </h1>
#   <hr/>
#   <div class="article">
#    <h2>
#     <a href="article_1.html">
#      Article 1 Headline
#     </a>
#    </h2>
#    <p>
#     This is a summary of article 1
#    </p>
#   </div>
#   <hr/>
#   <div class="article">
#    <h2>
#     <a href="article_2.html">
#      Article 2 Headline
#     </a>
#    </h2>
#    <p>
#     This is a summary of article 2
#    </p>
#   </div>
#   <hr/>
#   <div class="footer">
#    <p>
#     Footer Information
#    </p>
#   </div>
#   <script src="js/vendor/modernizr-3.5.0.min.js">
#   </script>
#   <script src="js/plugins.js">
#   </script>
#   <script src="js/main.js">
#   </script>
#  </body>
# </html>

# %%
# returns first occurance of tag
soup.div
# Out:
# <div class="article">
# <h2><a href="article_1.html">Article 1 Headline</a></h2>
# <p>This is a summary of article 1</p>
# </div>

# %%
article = soup.find('div', class_='article')
article
# Out:
# <div class="article">
# <h2><a href="article_1.html">Article 1 Headline</a></h2>
# <p>This is a summary of article 1</p>
# </div>

# %%
headline = article.h2.a.text
headline
# Out:
# 'Article 1 Headline'

# %%
summary = article.p.text
summary
# Out:
# 'This is a summary of article 1'

# %%
headlines, summaries = [], []
articles = soup.find_all('div', class_='article')
for article in articles:
    headlines.append(article.h2.a.text)
    summaries.append(article.p.text)

headlines, summaries
# Out:
# (['Article 1 Headline', 'Article 2 Headline'],
#  ['This is a summary of article 1', 'This is a summary of article 2'])

# %% [markdown]
# # Online Website

# %%
source = requests.get('https://www.writeoutloud.net/blogs/').text

# %%
soup = BeautifulSoup(source, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
#     Copyright 2005-2020 Write Out Loud 2015 CIC
# -->
# <html lang="en-gb">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, user-scalable=yes" name="viewport"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/images/wol-icon-196x196.png" rel="shortcut icon" sizes="196x196"/>
#   <link href="/images/wol-icon-32x32.png" rel="icon" sizes="32x32"/>
#   <link href="/images/wol-icon-120x120.png" rel="icon" sizes="120x120"/>
#   <link href="/images/wol-icon-196x196.png" rel="icon" sizes="196x196"/>
#   <link href="/images/wol-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/images/wol-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/images/wol-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/images/wol-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# ...

# %%
for i in range(120):
    print(soup.find_all('div', class_='entrytext')[2].find_all('p')[i].text)
# Out:
# That’s what makes us human,
# that we tell our stories;
# we tell not just theirs,
# not those of the powerful,
# but those of the women
# and those of the men,
# who all but survive,
# in our stinking back-alleys;
# so out I now venture,
# I, who have been sheltered,
# who am warm and well-fed,
# to collect from the shop
# poems written by many,
# for you and for you,
# for the muc...
#
# Read and leave comments (0)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[77], line 2
#       1 for i in range(120):
# ----> 2     print(soup.find_all('div', class_='entrytext')[2].find_all('p')[i].text)
#
# IndexError: list index out of range

# %%
soup.find('p', class_='entrydate smallfont')['style']
# Out:
# 'text-align: right; background-color: transparent'

# %%
try:
    pass
except:
    raise e

# %%
import csv

# %%
csv_file = open('cms_scrape.csv', 'w')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['headline',
                     'summary',
                     'video_link'])
# Out:
# 29

# %%
# csv_writer.writerow([headline, summary, yt_link])
csv_file.close()
